# %%
import pandas as pd
import numpy as np
import math
import statsmodels.discrete.discrete_model as sm
import json
import urllib2
import urllib
import random

standings_2016 = "2016Standings.csv"
standings_2015 = "2015Standings.csv"
comingfixtures = "comingfixtures.csv"

# %%
resp = urllib.urlopen("http://api.football-data.org/v1/competitions/426/leagueTable")
html = resp.read().decode('utf8')
dataLeagueJson = json.loads(html)

# %%
leagueTable = pd.DataFrame(columns=("Team", "Position"))
i = 0
for d in dataLeagueJson["standing"]:
    row =[d["teamName"], d["position"]]
    leagueTable.loc[i] = row
    i = i+1

teams = leagueTable["Team"].tolist()  
temp = leagueTable.set_index('Team').to_dict()
standings = temp["Position"]
fixtures = pd.DataFrame(columns=("Home", "Away"))

for j in range(0,10):
    t1 = random.choice(teams)
    teams.remove(t1)
    t2 = random.choice(teams)
    teams.remove(t2)
    row = list()
    row =[t1, t2]
    fixtures.loc[j] = row
    j = j+1

#fixtures.to_csv(comingfixtures, sep=',', encoding='utf-8')

fixtures
# Out:
#      2017-08-11               Arsenal FC        Leicester City FC
# 0    2017-08-12               Watford FC             Liverpool FC
# 1    2017-08-12  West Bromwich Albion FC          AFC Bournemouth
# 2    2017-08-12        Crystal Palace FC        Huddersfield Town
# 3    2017-08-12               Everton FC            Stoke City FC
# 4    2017-08-12           Southampton FC          Swansea City FC
# 5    2017-08-12               Chelsea FC               Burnley FC
# 6    2017-08-12   Brighton & Hove Albion       Manchester City FC
# 7    2017-08-13      Newcastle United FC     Tottenham Hotspur FC
# 8    2017-08-13     Manchester United FC       West Ham United FC
# 9    2017-08-19          Swansea City FC     Manchester United FC
# 10   2017-08-19           Southampton FC       West Ham United FC
# 11   2017-08-19          AFC Bournemouth               Watford FC
# 12   2017-08-19               Burnley FC  West Bromwich Albion FC
# 13   2017-08-19        Leicester City FC   Brighton & Hove Albion
# 14   2017-08-19             Liverpool FC        Crystal Palace FC
# 15   2017-08-19            Stoke City FC               Arsenal FC
# 16   2017-08-20        Huddersfield Town      Newcastle United FC
# 17   2017-08-20     Tottenham Hotspur FC               Chelsea FC
# 18   2017-08-21       Manchester City FC               Everton FC
# 19   2017-08-26          AFC Bournemouth       Manchester City FC
# 20   2017-08-26        Crystal Palace FC          Swansea City FC
# 21   2017-08-26        Huddersfield Town           Southampton FC
# 22   2017-08-26      Newcastle United FC       West Ham United FC
# 23   2017-08-26               Watford FC   Brighton & Hove Albion
# 24   2017-08-26     Manchester United FC        Leicester City FC
# 25   2017-08-27               Chelsea FC               Everton FC
# 26   2017-08-27  West Bromwich Albion FC            Stoke City FC
# 27   2017-08-27             Liverpool FC               Arsenal FC
# 28   2017-08-27     Tottenham Hotspur FC               Burnley FC
# 29   2017-09-09       Manchester City FC             Liverpool FC
# ..          ...                      ...                      ...
# 349  2018-04-28        Huddersfield Town               Everton FC
# 350  2018-04-28               Burnley FC   Brighton & Hove Albion
# 351  2018-04-28        Crystal Palace FC        Leicester City FC
# 352  2018-04-28             Liverpool FC            Stoke City FC
# 353  2018-04-28     Manchester United FC               Arsenal FC
# 354  2018-04-28      Newcastle United FC  West Bromwich Albion FC
# 355  2018-04-28           Southampton FC          AFC Bournemouth
# 356  2018-04-28          Swansea City FC               Chelsea FC
# 357  2018-04-28     Tottenham Hotspur FC               Watford FC
# 358  2018-04-28       West Ham United FC       Manchester City FC
# 359  2018-05-05   Brighton & Hove Albion     Manchester United FC
# 360  2018-05-05               Arsenal FC               Burnley FC
# 361  2018-05-05          AFC Bournemouth          Swansea City FC
# 362  2018-05-05            Stoke City FC        Crystal Palace FC
# 363  2018-05-05               Chelsea FC             Liverpool FC
# 364  2018-05-05               Everton FC           Southampton FC
# 365  2018-05-05        Leicester City FC       West Ham United FC
# 366  2018-05-05       Manchester City FC        Huddersfield Town
# 367  2018-05-05               Watford FC      Newcastle United FC
# 368  2018-05-05  West Bromwich Albion FC     Tottenham Hotspur FC
# 369  2018-05-13        Crystal Palace FC  West Bromwich Albion FC
# 370  2018-05-13        Huddersfield Town               Arsenal FC
# 371  2018-05-13             Liverpool FC   Brighton & Hove Albion
# 372  2018-05-13     Manchester United FC               Watford FC
# 373  2018-05-13      Newcastle United FC               Chelsea FC
# 374  2018-05-13           Southampton FC       Manchester City FC
# 375  2018-05-13          Swansea City FC            Stoke City FC
# 376  2018-05-13     Tottenham Hotspur FC        Leicester City FC
# 377  2018-05-13               Burnley FC          AFC Bournemouth
# 378  2018-05-13       West Ham United FC               Everton FC
#
# [379 rows x 3 columns]

# %%
leagueTable2015 = pd.read_csv(standings_2015)
temp = leagueTable2015.set_index('Team').to_dict()
standings2015 = temp["Position"]

leagueTable2015
# Out:
#     Unnamed: 0                     Team  Position
# 0            0        Leicester City FC         1
# 1            1               Arsenal FC         2
# 2            2     Tottenham Hotspur FC         3
# 3            3       Manchester City FC         4
# 4            4     Manchester United FC         5
# 5            5           Southampton FC         6
# 6            6       West Ham United FC         7
# 7            7             Liverpool FC         8
# 8            8            Stoke City FC         9
# 9            9               Chelsea FC        10
# 10          10               Everton FC        11
# 11          11          Swansea City FC        12
# 12          12               Watford FC        13
# 13          13  West Bromwich Albion FC        14
# 14          14        Crystal Palace FC        15
# 15          15          AFC Bournemouth        16
# 16          16           Sunderland AFC        17
# 17          17         Middlesbrough FC        18
# 18          18             Hull City FC        18
# 19          19               Burnley FC        18

# %%
bigFixtures = pd.DataFrame(columns=("Home", "Away"))

# %%
#Home teams standings this season till date
fixtures["HS"] = fixtures['Home'].map(standings)

#Away teams standings this season till date
fixtures["AS"] = fixtures['Away'].map(standings)

#Diff
fixtures["Diff"] = abs(fixtures["HS"] - fixtures["AS"])

#Same stuff for last season
fixtures["LHS"] = fixtures['Home'].map(standings2015)
fixtures["LAS"] = fixtures['Away'].map(standings2015)
fixtures["LDiff"] = abs(fixtures["LHS"] - fixtures["LAS"])

fixtures
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-dd4f6e998601> in <module>()
#       1 #Home teams standings this season till date
# ----> 2 fixtures["HS"] = fixtures['Home'].map(standings)
#       3
#       4 #Away teams standings this season till date
#       5 fixtures["AS"] = fixtures['Away'].map(standings)
#
# C:\Users\Pranit\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Users\Pranit\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\Users\Pranit\Anaconda2\lib\site-packages\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# C:\Users\Pranit\Anaconda2\lib\site-packages\pandas\core\internals.pyc in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\Pranit\Anaconda2\lib\site-packages\pandas\indexes\base.pyc in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'Home'

# %%
#Constraints for current standings
bigFixtures1 = fixtures.loc[fixtures["Diff"] > 9 ]
bigFixtures2 = fixtures.loc[((fixtures["HS"] < 10) & (fixtures["AS"] < 10)) ]
bigFixtures3 = fixtures.loc[((fixtures["HS"] > 17) & (fixtures["AS"] > 17)) ]

#Constraints for last year's standings (Made them stricter)
bigFixtures4 = fixtures.loc[fixtures["LDiff"] > 12 ]
bigFixtures5 = fixtures.loc[((fixtures["LHS"] < 7) & (fixtures["LAS"] < 7)) ]
bigFixtures6 = fixtures.loc[((fixtures["LHS"] > 17) & (fixtures["LAS"] > 17)) ]

#Take last year's top 4
bigFixtures7 = fixtures.loc[(fixtures["LHS"] <= 4)]

bigFixtures = bigFixtures1.append(bigFixtures2).append(bigFixtures3).append(bigFixtures4).append(bigFixtures5).append(bigFixtures6).append(bigFixtures7)
bigFixtures.drop_duplicates(inplace=True)

bigFixtures
